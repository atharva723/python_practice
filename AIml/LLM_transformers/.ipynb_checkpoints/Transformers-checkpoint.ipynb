# %% [markdown]
# # Transformers, Self-Attention, BERT, GPT

# %% [raw]
# 1. Why Transformers? (What Problem They Solve)
#
# Before Transformers, NLP models used:
#
# ✔ RNN
# ✔ LSTM
# ✔ GRU

# %% [raw]
# Limitations of RNN/LSTM (Why we need Transformers)

# %% [raw]
# 1. Sequential Processing → Slow
# He → reads → every → word → step → by → step
# You cannot parallelize this.

# %% [raw]
# 2. Long-term dependency problem
# Even LSTM struggles when the important information is far away:
#
# The book that John gave to Mary,
# who lives in France...
# ...was expensive.

# %% [raw]
# Model must connect “book” ↔ “was expensive”, which are 15–30 tokens apart.

# %% [raw]
# 3. Memory bottleneck
# Hidden state = single vector capturing all past context → compresses too much.
#
# 4. Slow training
# No GPU-friendly parallel matrix multiplication.

# %% [raw]
# Transformers solve all 4 problems at once
# 🌟 Key ideas
#
# Self-Attention
# Layer Normalization + Residuals
# Multi-Head Attention
# Fully Parallel Processing
# This changed NLP forever.

# %%
#!pip install transformers torch datasets sentencepiece accelerate

# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import (
    pipeline,
    AutoTokenizer,
    AutoModel,
    AutoModelForMaskedLM,
    AutoModelForSequenceClassification,
    AutoModelForCausalLM
)

# %% [markdown]
# ## Self-Attention: The Core Idea

# %% [raw]
# This is the entire reason Transformers replaced RNN/LSTM.
#
# Self-attention answers:
#
# 👉 "For every word, how much attention should I pay to every other word?"
#
# The cat sat on the mat because it was warm.
# it → refers to → the mat
#
# A standard RNN cannot do this well.

# %% [raw]
# 🔥 Self-Attention calculates relationships directly
#
# For each word we compute:
#
# Q = Query
# K = Key
# V = Value
#
# Using learned matrices:
#
# Q = XWq
# K = XWk
# V = XWv
#
# Then attention score is:
#
# Attention(Q, K, V) = Softmax( Q * Kᵀ / √d ) * V
#
# This tells the model:
#
# Which words matter
# How much they matter
# How to combine them

# %% [raw]
# 🧠 Intuition of Q, K, V
#
# Query (Q): “What are you looking for?”
# Key (K): “What do I contain?”
# Value (V): “What information should you take from me?”
# Let’s take the sentence: I want to book a flight to Paris.
#
# When predicting “Paris,” the model should attend to “flight” and “to” — Q/K/V make this possible.

# %% [markdown]
# ### Multi-Head Attention (Why many heads?)

# %% [raw]
# Instead of a single attention pattern, the model learns many patterns in parallel.
#
# Each head focuses on something different:
#
# Head 1 → subject-verb relationship
# Head 2 → nouns
# Head 3 → objects
# Head 4 → locations
#
# This is like having multiple interpreters reading the sentence.

# %% [raw]
# Visualize self-attention using PyTorch

# %% [markdown]
# Visualize self-attention using PyTorch

# %%
import torch
import torch.nn.functional as F

# Dummy sequence of 5 tokens, embedding dim = 4
x = torch.randn(5, 4)

Wq = torch.randn(4, 4)
Wk = torch.randn(4, 4)
Wv = torch.randn(4, 4)

Q = x @ Wq
K = x @ Wk
V = x @ Wv

scores = (Q @ K.T) / (4 ** 0.5)   # scaled dot-product attention
attn = F.softmax(scores, dim=-1)

context_vector = attn @ V

attn, context_vector

# %% [markdown]
# ### Transformer Architecture (Encoder/Decoder)

# %% [raw]
# +-------------------------------+
# |        Transformer            |
# +---------------+---------------+
# |   Encoder     |   Decoder     |
# +---------------+---------------+

# %% [raw]
# ✔ Encoder (BERT-like models)
#
# Bidirectional attention
# Reads full context
# Best for classification, embeddings, semantic tasks
#
# ✔ Decoder (GPT-like models)
#
# Left-to-right attention
# Predicts next token
# Best for generation

# %% [markdown]
# BERT Explained (Encoder Only)

# %% [raw]
# ✔ BERT uses Bidirectional attention
#
# It reads sentences in both directions: The [MASK] sat on the mat.
#
# BERT predicts:
# “cat”
#
# BERT pretraining tasks:
#
# 1. Masked Language Modeling
# (Hides tokens and predicts them)
#
# 2. Next Sentence Prediction
# (Understood relationships between sentences)
#
# This makes BERT perfect for:
# ✔ Classification
# ✔ NER
# ✔ Semantic search
# ✔ Q&A
# ✔ Embeddings

# %%
from transformers import pipeline
bert = pipeline("fill-mask", model="bert-base-uncased")
bert("The capital of France is [MASK].")

# %% [markdown]
# ### GPT Explained (Decoder Only)

# %% [raw]
# GPT uses causal attention (no looking ahead):
#
# I like to eat ice
#            ^
#            predict “cream”

# %% [raw]
# GPT pretraining:
#
# ✔ Next-token prediction
#
# This makes GPT ideal for:
#
# Chatbots
# Generation
# Summarization
# Code generation
# Agentic AI
# Reasoning

# %%
from transformers import pipeline
gpt = pipeline("text-generation", model="gpt2")
gpt("Once upon a time in Bangalore,")[0]["generated_text"]

# %% [markdown]
# #### BERT vs GPT (Simple Table)

# %% [raw]
# | Feature   | BERT           | GPT                   |
# | --------- | -------------- | --------------------- |
# | Type      | Encoder        | Decoder               |
# | Direction | Bidirectional  | Left → Right          |
# | Task      | Understanding  | Generation            |
# | Training  | Masked LM      | Next-token prediction |
# | Best for  | Classification | Text Generation       |

# %% [markdown]
# #### Self-Attention is Parallel → Fast on GPUs

# %% [raw]
# RNN:
# t1 → t2 → t3 → t4 → t5 (sequential)
#
# Transformer attention:
# t1  t2  t3  t4  t5 (all parallel)
#
# This is why GPT-4 can be trained on thousands of GPUs.

# %% [raw]
# Positional Encoding — Why Needed?
#
# Transformers don’t know order by default.
# So we add sinusoidal patterns: sin(position), cos(position)
#
# This lets model know:
# token #1
# token #2
# token #3
# token #....

# %%
def positional_encoding(seq_len, d_model):
    PE = torch.zeros(seq_len, d_model)
    pos = torch.arange(0, seq_len).unsqueeze(1).float()  # shape [seq_len, 1]

    for i in range(0, d_model, 2):
        div_term = 10000 ** (i / d_model)
        PE[:, i] = torch.sin(pos.squeeze(1) / div_term)  # shape [seq_len]
        PE[:, i+1] = torch.cos(pos.squeeze(1) / div_term)
    return PE

PE = positional_encoding(50, 16)

plt.figure(figsize=(8,4))
sns.heatmap(PE.numpy(), cmap="viridis")
plt.title("Positional Encoding Pattern")
plt.show()

# %% [markdown]
# Full Transformer Block Diagram

# %% [raw]
# Input Embedding + Position
#         │
#         ▼
# +------------------------+
# |   Multi-Head Attention |
# +------------------------+
#         │
#    Add & Norm
#         │
#         ▼
# +------------------------+
# |  Feed Forward (MLP)    |
# +------------------------+
#         │
#    Add & Norm
#         ▼
#    Output

# %% [markdown]
# Mini Transformer Attention Visualization (HF)

# %%
from transformers import AutoModel, AutoTokenizer
import torch

model = AutoModel.from_pretrained("bert-base-uncased", output_attentions=True)
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

inputs = tokenizer("Hello I am learning transformers!", return_tensors="pt")
outputs = model(**inputs)

attn = outputs.attentions  
len(attn), attn[0].shape   # (layers, batch, heads, tokens, tokens)
# Out:
# (12, torch.Size([1, 12, 8, 8]))

# %%
#!pip install tf-keras

# %%
from transformers import pipeline

fill = pipeline("fill-mask", model="bert-base-uncased")
fill("The capital of France is [MASK].")
# Out:
# WARNING:tensorflow:From C:\Users\admin\.conda\envs\tf\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'score': 0.416788786649704,
#   'token': 3000,
#   'token_str': 'paris',
#   'sequence': 'the capital of france is paris.'},
#  {'score': 0.07141651213169098,
#   'token': 22479,
#   'token_str': 'lille',
#   'sequence': 'the capital of france is lille.'},
#  {'score': 0.06339280307292938,
#   'token': 10241,
#   'token_str': 'lyon',
#   'sequence': 'the capital of france is lyon.'},
#  {'score': 0.04444750398397446,
#   'token': 16766,
#   'token_str': 'marseille',
#   'sequence': 'the capital of france is marseille.'},
#  {'score': 0.03029724210500717,
#   'token': 7562,
#   'token_str': 'tours',
#   'sequence': 'the capital of france is tours.'}]

# %%
clf = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")

clf("what a match of cricket it was, our team played so well that they dropped all catches!")

# %% [markdown]
# BERT Sentence Embeddings (Used in RAG, LangChain)

# %%
tok = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModel.from_pretrained("bert-base-uncased")

text = "Transformers changed deep learning forever."
tokens = tok(text, return_tensors="pt")

with torch.no_grad():
    output = model(**tokens).last_hidden_state
    embedding = output.mean(dim=1)

embedding.shape
# Out:
# torch.Size([1, 768])

# %%
embedding
# Out:
# tensor([[ 4.8118e-01,  2.2255e-02,  2.3437e-01,  2.9283e-01,  1.5477e-01,
#          -3.5160e-01,  3.6276e-01,  6.6813e-01,  2.6318e-01, -6.2313e-01,
#           3.3251e-01, -1.2680e-01,  4.0204e-02,  4.2963e-01, -8.1283e-02,
#           9.4664e-03, -9.2769e-03, -2.1423e-01,  1.2391e-01,  2.1578e-01,
#          -5.5755e-02,  4.9718e-02, -1.1202e-02,  7.2107e-01,  2.4249e-01,
#          -7.8887e-02, -1.3534e-01, -4.6789e-02, -2.8825e-01, -2.0091e-01,
#          -4.5834e-02, -1.0742e-01, -1.5397e-02, -2.3608e-01, -2.8766e-01,
#          -7.1730e-02, -1.3620e-01, -2.9062e-01, -2.6933e-01, -5.8896e-02,
#          -5.6685e-01, -7.8516e-02,  6.8911e-02,  1.5713e-03, -1.7109e-01,
#           3.9922e-04, -2.2543e-01, -8.7175e-02,  1.0485e-01, -1.0569e-01,
#          -1.3154e-01, -4.8225e-02,  1.5725e-01,  1.5575e-01, -8.4316e-02,
#           4.2958e-01,  1.1856e-01, -2.9336e-01, -1.3419e-01,  1.0632e-01,
#           2.0947e-01,  4.6667e-01, -2.2501e-01, -1.9839e-01,  1.0379e-01,
#          -4.9919e-01, -4.4031e-01,  1.9331e-01, -1.7781e-02, -3.4258e-01,
#          -8.4639e-02,  3.3258e-03, -2.8140e-01,  3.7292e-02, -2.7710e-01,
#           6.6021e-03, -1.6486e-01,  7.0751e-02,  4.8185e-02,  1.7281e-01,
#          -1.2109e-01,  3.9353e-01, -6.1201e-02,  4.0577e-01, -3.3695e-01,
#          -4.4922e-01,  2.2250e-01, -8.7684e-02,  1.6463e-01,  7.4794e-02,
#           9.0791e-02, -3.3235e-02, -1.1691e-01,  1.0129e-01,  2.5959e-01,
#          -1.1789e+00,  3.2152e-01, -1.4830e-01, -6.3986e-02, -8.8724e-02,
#          -5.7297e-02, -1.8329e-01,  2.6761e-01, -3.0219e-01, -3.8202e-02,
#          -6.1624e-02,  1.6250e-01, -5.3562e-01, -3.4404e-02, -3.2893e-01,
#           6.5040e-01, -2.1342e-02,  9.7925e-02, -8.7731e-02,  1.6244e-01,
#          -1.3632e-02, -4.3810e-02,  3.9966e-01,  4.6654e-02, -2.6360e-01,
#           9.0396e-03,  6.3811e-03, -3.1021e-01,  1.1234e-01,  6.1210e-02,
#           2.0620e-01,  1.3688e-01, -1.9515e+00, -1.8046e-01,  2.0871e-02,
#           6.6129e-02,  8.4927e-02, -1.8865e-01,  1.5340e-01,  9.3522e-02,
#           1.6355e-01, -2.2999e-01,  1.1518e-01, -2.3962e-01, -1.9293e-02,
#          -2.3268e-01,  1.9609e-01, -2.5191e-02]])

# %% [markdown]
# BERT Attention Heatmap

# %%
model = AutoModel.from_pretrained("bert-base-uncased", output_attentions=True)
tok = AutoTokenizer.from_pretrained("bert-base-uncased")

inputs = tok("Attention is all you need", return_tensors="pt")
outputs = model(**inputs)

attn = outputs.attentions[0][0]   # 1st layer, 1st batch = (heads, tokens, tokens)

plt.figure(figsize=(8,4))
sns.heatmap(attn.mean(0).detach().numpy(), cmap="Reds")
plt.title("BERT Attention Heatmap (Layer 1, Avg Heads)")
plt.show()

# %%
gen = pipeline("text-generation", model="gpt2", max_length=60)
gen("Once upon a time in Bangalore")[0]["generated_text"]

# %%
print("\n--- BERT (Understanding) ---")
print(fill("The weather today is very [MASK]."))

print("\n--- GPT (Generation) ---")
print(gen("The weather today is very")[0]["generated_text"])

# %% [raw]
# 🧩 When to Use What (Final Summary)
# 🔵 Use BERT for understanding
#
# Classification
# Sentiment
# NER
# Semantic Search
# RAG embeddings
# Topic detection
# Document similarity
#
# 🔴 Use GPT for generating
#
# Chatbots
# Summaries
# Story writing
# Code generation
# Reasoning agents (LangChain, MCP)

# %% [markdown]
# How Transformers Power Agentic AI

# %% [raw]
# Transformers →
#
# Give embeddings
# Provide reasoning
# Support function calling
# Enable tool use
# Can be fine-tuned to behave like agents
#
# BERT →
# Used in vector DBs, similarity, retrieval.
#
# GPT →
# Used for reasoning, planning, routing, tool orchestration.
# Without Transformers, agentic systems wouldn’t be possible.
