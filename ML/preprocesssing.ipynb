# %% [markdown]
# preprocessing

# %% [raw]
# pip install nltk

# %%
import nltk

# %%
text="The September 11 attacks were precipitated in large part because Osama bin Laden, the leader of the militant Islamic organization al-Qaeda, held naive beliefs about the United States in the run-up to the attacks. Abu Walid al-Masri, an Egyptian who was a bin Laden associate in Afghanistan in the 1980s and ’90s, explained that, in the years prior to the attacks, bin Laden became increasingly convinced that America was weak. “He believed that the United States was much weaker than some of those around him thought,” Masri remembered, and “as evidence he referred to what happened to the United States in Beirut when the bombing of the Marines base led them to flee from Lebanon,” referring to the destruction of the marine barracks there in 1983 (see 1983 Beirut barracks bombings), which killed 241 American servicemen. Bin Laden believed that the United States was a “paper tiger,” a belief shaped not just by America’s departure from Lebanon following the marine barracks bombing but also by the withdrawal of American forces from Somalia in 1993, following the deaths of 18 U.S. servicemen in Mogadishu, and the American pullout from Vietnam in the 1970s."

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
import nltk
nltk.download("punkt")
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Atharva\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Atharva\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
word_tokens = sent_tokenize(text)

# %%
word_tokens
# Out:
# ['The September 11 attacks were precipitated in large part because Osama bin Laden, the leader of the militant Islamic organization al-Qaeda, held naive beliefs about the United States in the run-up to the attacks.',
#  'Abu Walid al-Masri, an Egyptian who was a bin Laden associate in Afghanistan in the 1980s and ’90s, explained that, in the years prior to the attacks, bin Laden became increasingly convinced that America was weak.',
#  '“He believed that the United States was much weaker than some of those around him thought,” Masri remembered, and “as evidence he referred to what happened to the United States in Beirut when the bombing of the Marines base led them to flee from Lebanon,” referring to the destruction of the marine barracks there in 1983 (see 1983 Beirut barracks bombings), which killed 241 American servicemen.',
# ...

# %% [markdown]
# TOKENIZTATION

# %%
from string  import punctuation

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
text="Wow! Did you see that? It's amazing—truly incredible—how quickly things can change; isn't it"

# %%
word_tokens = word_tokenize(text)

# %%
word_tokens
# Out:
# ['Wow',
#  '!',
#  'Did',
#  'you',
#  'see',
#  'that',
#  '?',
#  'It',
#  "'s",
#  'amazing—truly',
#  'incredible—how',
#  'quickly',
#  'things',
#  'can',
#  'change',
#  ';',
#  'is',
#  "n't",
#  'it']

# %%
clean_data= [i for i in word_tokens if i not in punctuation]

# %%
clean_data
# Out:
# ['Wow',
#  'Did',
#  'you',
#  'see',
#  'that',
#  'It',
#  "'s",
#  'amazing—truly',
#  'incredible—how',
#  'quickly',
#  'things',
#  'can',
#  'change',
#  'is',
#  "n't",
#  'it']

# %% [markdown]
# NORMALIZATION

# %%
lowercase= [i.title() for i in clean_data]
lowercase
#i.title, i.casefold(),
# Out:
# ['Wow',
#  'Did',
#  'You',
#  'See',
#  'That',
#  'It',
#  "'S",
#  'Amazing—Truly',
#  'Incredible—How',
#  'Quickly',
#  'Things',
#  'Can',
#  'Change',
#  'Is',
#  "N'T",
#  'It']

# %%
a = "HOla, mY NaMe iS aThaRva"

# %%
a.title()
# Out:
# 'Hola, My Name Is Atharva'

# %%
a.upper()
# Out:
# 'HOLA, MY NAME IS ATHARVA'

# %%
a.capitalize()
# Out:
# 'Hola, my name is atharva'

# %%
a.find("mY")
# Out:
# 6

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Atharva\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
lowercase ='Hello My name is ATharva'

# %%
stopwords_removed = [i for i in lowercase if i not in stop]
stopwords_removed
# Out:
# ['H',
#  'e',
#  'l',
#  'l',
#  ' ',
#  'M',
#  ' ',
#  'n',
#  'e',
#  ' ',
#  ' ',
#  'A',
#  'T',
#  'h',
#  'r',
#  'v']

# %%
m = open('stopwords-mr.txt')

# %%
words = nltk.word_tokenize(text)

# %%
filtered_words = [i for]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[233], line 1
# ----> 1 filtered_words = [i for i in words if word not in m]
#
# Cell In[233], line 1, in <listcomp>(.0)
# ----> 1 filtered_words = [i for i in words if word not in m]
#
# NameError: name 'word' is not defined

# %% [markdown]
# Steming

# %%
from nltk.stem import LancasterStemmer, WordNetLemmatizer

# %%
stemming = LancasterStemmer()

# %%
for i in stopwords_removed:
    text= stemming.stem(i)
    print(text)
# Out:
# h
# e
# l
# l
#
# m
#
# n
# e
#
#
# a
# t
# h
# r
# v

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Atharva\AppData\Roaming\nltk_data...
# True

# %% [markdown]
# lemmatization

# %%
lemma = WordNetLemmatizer()
for i in stopwords_removed:
    text=lemma.lemmatize(i,pos='v')
    print(text)
# Out:
# H
# e
# l
# l
#
# M
#
# n
# e
#
#
# A
# T
# h
# r
# v

# %%
# Out:
# v
