# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"C:\Users\Atharva\Desktop\ML\logistic\diabetes.csv")
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 df = pd.read_csv(r"C:\Users\Atharva\Desktop\ML\logistic\diabetes.csv")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\__init__.py:39
#      35 del _hard_dependencies, _dependency, _missing_dependencies
#      37 try:
#      38     # numpy compat
# ---> 39     from pandas.compat import (
#      40         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401
#      41     )
#      42 except ImportError as _err:  # pragma: no cover
#      43     _module = _err.name
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\compat\__init__.py:26
#      17 from pandas.compat._constants import (
#      18     IS64,
#      19     ISMUSL,
#    (...)
#      23     PYPY,
#      24 )
# ...

# %% [raw]
# pip install numpy

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import pandas as pd
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\__init__.py:39
#      35 del _hard_dependencies, _dependency, _missing_dependencies
#      37 try:
#      38     # numpy compat
# ---> 39     from pandas.compat import (
#      40         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401
#      41     )
#      42 except ImportError as _err:  # pragma: no cover
#      43     _module = _err.name
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\compat\__init__.py:26
#      17 from pandas.compat._constants import (
#      18     IS64,
#      19     ISMUSL,
#    (...)
#      23     PYPY,
#      24 )
#      25 import pandas.compat.compressors
# ---> 26 from pandas.compat.numpy import is_numpy_dev
# ...
