# %%
import pandas as pd

# %%
df=pd.read_csv('csv/oj.csv')

# %%
df.head(8)
# Out:
#    store      brand  week   logmove  feat  price     AGE60      EDUC   ETHNIC  \
# 0      2  tropicana    40  9.018695     0   3.87  0.232865  0.248935  0.11428
# 1      2  tropicana    46  8.723231     0   3.87  0.232865  0.248935  0.11428
# 2      2  tropicana    47  8.253228     0   3.87  0.232865  0.248935  0.11428
# 3      2  tropicana    48  8.987197     0   3.87  0.232865  0.248935  0.11428
# 4      2  tropicana    50  9.093357     0   3.87  0.232865  0.248935  0.11428
# 5      2  tropicana    51  8.877382     0   3.87  0.232865  0.248935  0.11428
# 6      2  tropicana    52  9.294682     0   3.29  0.232865  0.248935  0.11428
# 7      2  tropicana    53  8.954674     0   3.29  0.232865  0.248935  0.11428
#
#       INCOME   HHLARGE   WORKWOM   HVAL150  SSTRDIST   SSTRVOL  CPDIST5  \
# 0  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 1  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# ...

# %%
## Find the dimensions of the oj data set

# %%
df.shape
# Out:
# (28947, 17)

# %%
## Find the structure of the data set

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28947 entries, 0 to 28946
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   store     28947 non-null  int64
#  1   brand     28947 non-null  str
#  2   week      28947 non-null  int64
#  3   logmove   28947 non-null  float64
#  4   feat      28947 non-null  int64
#  5   price     28947 non-null  float64
#  6   AGE60     28947 non-null  float64
#  7   EDUC      28947 non-null  float64
#  8   ETHNIC    28947 non-null  float64
#  9   INCOME    28947 non-null  float64
#  10  HHLARGE   28947 non-null  float64
#  11  WORKWOM   28947 non-null  float64
#  12  HVAL150   28947 non-null  float64
#  13  SSTRDIST  28947 non-null  float64
#  14  SSTRVOL   28947 non-null  float64
#  15  CPDIST5   28947 non-null  float64
#  16  CPWVOL5   28947 non-null  float64
# dtypes: float64(13), int64(3), str(1)
# memory usage: 3.8 MB

# %%
##Find out the column names in the data set

# %%
df.columns
# Out:
# Index(['store', 'brand', 'week', 'logmove', 'feat', 'price', 'AGE60', 'EDUC',
#        'ETHNIC', 'INCOME', 'HHLARGE', 'WORKWOM', 'HVAL150', 'SSTRDIST',
#        'SSTRVOL', 'CPDIST5', 'CPWVOL5'],
#       dtype='str')

# %%
##Describe the data set

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        store      brand  week    logmove  feat  price     AGE60      EDUC  \
# 0          2  tropicana    40   9.018695     0   3.87  0.232865  0.248935
# 1          2  tropicana    46   8.723231     0   3.87  0.232865  0.248935
# 2          2  tropicana    47   8.253228     0   3.87  0.232865  0.248935
# 3          2  tropicana    48   8.987197     0   3.87  0.232865  0.248935
# 4          2  tropicana    50   9.093357     0   3.87  0.232865  0.248935
# ...      ...        ...   ...        ...   ...    ...       ...       ...
# 28942    137  dominicks   156   7.987524     0   2.00  0.209602  0.528362
# 28943    137  dominicks   157   8.502689     0   1.94  0.209602  0.528362
# 28944    137  dominicks   158   9.505991     0   1.59  0.209602  0.528362
# 28945    137  dominicks   159  10.927376     0   1.49  0.209602  0.528362
# 28946    137  dominicks   160   8.859363     0   1.75  0.209602  0.528362
#
# ...

# %%
##Update the column names of the data set, such that every column name is in lowercase

# %%
col_l=[]
for i in df.columns:
    col_l.append(i.lower())
df.columns=col_l

# %%
##Fetch the first-row 3rd column from the data set

# %%
df.iloc[0,2]
# Out:
# np.int64(40)

# %%
##Fetch the first, second and Third columns of the oj data frame

# %%
df.iloc[::,0:3]
# Out:
#        store      brand  week
# 0          2  tropicana    40
# 1          2  tropicana    46
# 2          2  tropicana    47
# 3          2  tropicana    48
# 4          2  tropicana    50
# ...      ...        ...   ...
# 28942    137  dominicks   156
# 28943    137  dominicks   157
# 28944    137  dominicks   158
# 28945    137  dominicks   159
# 28946    137  dominicks   160
#
# [28947 rows x 3 columns]

# %%
##Fetch the first, second, eighth and the 456th rows of the 1st, third and the sixth columns of the data frame

# %%
df.iloc[[1,2,8,455],[3,6]]
# Out:
#       logmove     age60
# 1    8.723231  0.232865
# 2    8.253228  0.232865
# 8    9.049232  0.232865
# 455  8.540910  0.117368

# %%
##Fetch the top 5 rows of the brand column

# %%
df['brand'].head(5)
# Out:
# 0    tropicana
# 1    tropicana
# 2    tropicana
# 3    tropicana
# 4    tropicana
# Name: brand, dtype: str

# %%
##Fetch top 5 rows of the brand, week and feat details

# %%
df[['brand','week','feat']].head(5)
# Out:
#        brand  week  feat
# 0  tropicana    40     0
# 1  tropicana    46     0
# 2  tropicana    47     0
# 3  tropicana    48     0
# 4  tropicana    50     0

# %%
##Fetch the details of all distinct stores

# %%
df['store'].unique
# Out:
# <bound method Series.unique of 0          2
# 1          2
# 2          2
# 3          2
# 4          2
#         ...
# 28942    137
# 28943    137
# 28944    137
# 28945    137
# 28946    137
# Name: store, Length: 28947, dtype: int64>

# %%
##Fetch all the observations for Tropicana brand using query function

# %%
df.query("brand=='tropicana'")
# Out:
#        store      brand  week    logmove  feat  price     age60      educ  \
# 0          2  tropicana    40   9.018695     0   3.87  0.232865  0.248935
# 1          2  tropicana    46   8.723231     0   3.87  0.232865  0.248935
# 2          2  tropicana    47   8.253228     0   3.87  0.232865  0.248935
# 3          2  tropicana    48   8.987197     0   3.87  0.232865  0.248935
# 4          2  tropicana    50   9.093357     0   3.87  0.232865  0.248935
# ...      ...        ...   ...        ...   ...    ...       ...       ...
# 28746    137  tropicana   156  11.313498     1   2.49  0.209602  0.528362
# 28747    137  tropicana   157  10.628133     0   2.66  0.209602  0.528362
# 28748    137  tropicana   158   9.936535     0   3.11  0.209602  0.528362
# 28749    137  tropicana   159  10.855917     1   2.79  0.209602  0.528362
# 28750    137  tropicana   160  10.236525     0   2.88  0.209602  0.528362
#
#         ethnic     income   hhlarge   workwom   hval150  sstrdist   sstrvol  \
# ...

# %%
##Fetch the columns store, brand and price for observations that belong to the brand tropicana

# %%
df[['store','brand','price']][df["brand"]=='tropicana']
# Out:
#        store      brand  price
# 0          2  tropicana   3.87
# 1          2  tropicana   3.87
# 2          2  tropicana   3.87
# 3          2  tropicana   3.87
# 4          2  tropicana   3.87
# ...      ...        ...    ...
# 28746    137  tropicana   2.49
# 28747    137  tropicana   2.66
# 28748    137  tropicana   3.11
# 28749    137  tropicana   2.79
# 28750    137  tropicana   2.88
#
# [9649 rows x 3 columns]

# %%
##Fetch bottom 5 observations for those who have bought Tropicana or dominics

# %%
df[(df['brand']=='tropicana') | (df['brand']=='dominics')].tail(5)
# Out:
#        store      brand  week    logmove  feat  price     age60      educ  \
# 28746    137  tropicana   156  11.313498     1   2.49  0.209602  0.528362
# 28747    137  tropicana   157  10.628133     0   2.66  0.209602  0.528362
# 28748    137  tropicana   158   9.936535     0   3.11  0.209602  0.528362
# 28749    137  tropicana   159  10.855917     1   2.79  0.209602  0.528362
# 28750    137  tropicana   160  10.236525     0   2.88  0.209602  0.528362
#
#         ethnic    income   hhlarge   workwom   hval150  sstrdist   sstrvol  \
# 28746  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28747  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28748  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28749  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28750  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
#
#        cpdist5   cpwvol5
# 28746  0.77253  0.333761
# ...

# %%
##Fetch the income, brand, price observations with Tropicana brand without the feature advertisement (feat ==0)

# %%
df[(df['brand']=='tropicana') & (df['feat']==0)][['income','brand','price']]
# Out:
#           income      brand  price
# 0      10.553205  tropicana   3.87
# 1      10.553205  tropicana   3.87
# 2      10.553205  tropicana   3.87
# 3      10.553205  tropicana   3.87
# 4      10.553205  tropicana   3.87
# ...          ...        ...    ...
# 28743  10.966490  tropicana   3.19
# 28745  10.966490  tropicana   2.77
# 28747  10.966490  tropicana   2.66
# 28748  10.966490  tropicana   3.11
# 28750  10.966490  tropicana   2.88
#
# [8045 rows x 3 columns]

# %%
##Remove the column normInc from the data frame

# %%
df.columns
# Out:
# Index(['store', 'brand', 'week', 'logmove', 'feat', 'price', 'age60', 'educ',
#        'ethnic', 'income', 'hhlarge', 'workwom', 'hval150', 'sstrdist',
#        'sstrvol', 'cpdist5', 'cpwvol5'],
#       dtype='str')

# %%
##Fetch the observations for the tropicana brand excluding the store, price and income fields

# %%
df.query("brand=='tropicana'").drop(columns=['store','price','income'])
# Out:
#            brand  week    logmove  feat     age60      educ   ethnic  \
# 0      tropicana    40   9.018695     0  0.232865  0.248935  0.11428
# 1      tropicana    46   8.723231     0  0.232865  0.248935  0.11428
# 2      tropicana    47   8.253228     0  0.232865  0.248935  0.11428
# 3      tropicana    48   8.987197     0  0.232865  0.248935  0.11428
# 4      tropicana    50   9.093357     0  0.232865  0.248935  0.11428
# ...          ...   ...        ...   ...       ...       ...      ...
# 28746  tropicana   156  11.313498     1  0.209602  0.528362  0.11325
# 28747  tropicana   157  10.628133     0  0.209602  0.528362  0.11325
# 28748  tropicana   158   9.936535     0  0.209602  0.528362  0.11325
# 28749  tropicana   159  10.855917     1  0.209602  0.528362  0.11325
# 28750  tropicana   160  10.236525     0  0.209602  0.528362  0.11325
#
#         hhlarge   workwom   hval150  sstrdist   sstrvol  cpdist5   cpwvol5
# ...

# %%
##Sort the Data in the increasing order of the week

# %%
df.sort_values(by='week',ascending=True)
# Out:
#        store        brand  week    logmove  feat  price     age60      educ  \
# 0          2    tropicana    40   9.018695     0   3.87  0.232865  0.248935
# 3837      40    tropicana    40   8.743851     0   2.59  0.181852  0.072129
# 20119    105    dominicks    40   8.050703     1   1.59  0.175542  0.094236
# 5803      49    dominicks    40   9.240287     1   1.59  0.187473  0.319950
# 19881    105    tropicana    40   8.565602     0   3.19  0.175542  0.094236
# ...      ...          ...   ...        ...   ...    ...       ...       ...
# 8256      59  minute.maid   160  10.377483     1   2.09  0.110819  0.233036
# 8372      59    dominicks   160   9.034080     0   1.63  0.110819  0.233036
# 20954    107    dominicks   160   8.987197     0   2.13  0.261867  0.273052
# 1844      14    tropicana   160   9.276877     0   3.41  0.213949  0.348293
# 20834    107  minute.maid   160  11.157393     1   2.19  0.261867  0.273052
#
# ...

# %%
##Sort the data in the decreasing order of Income and increasing order of week

# %%
df.sort_values(by=['income','week'],ascending=[False,True])
# Out:
#        store        brand  week    logmove  feat  price     age60      educ  \
# 8373      62    tropicana    40   9.373819     0   3.87  0.222534  0.517760
# 8490      62  minute.maid    40   8.449343     0   3.17  0.222534  0.517760
# 8607      62    dominicks    40   8.050703     1   1.59  0.222534  0.517760
# 8374      62    tropicana    41   9.368369     0   3.87  0.222534  0.517760
# 8491      62  minute.maid    41  10.667652     1   1.99  0.222534  0.517760
# ...      ...          ...   ...        ...   ...    ...       ...       ...
# 11724     75  minute.maid   159   8.540910     0   2.64  0.207699  0.219548
# 11842     75    dominicks   159  10.806571     0   1.49  0.207699  0.219548
# 11607     75    tropicana   160   9.114710     0   2.88  0.207699  0.219548
# 11725     75  minute.maid   160  10.747810     1   2.19  0.207699  0.219548
# 11843     75    dominicks   160   9.436998     0   1.71  0.207699  0.219548
#
# ...

# %%
##Find the mean of the juice price for each brand
df.loc[df['brand']=='tropicana']
# Out:
#        store      brand  week    logmove  feat  price     age60      educ  \
# 0          2  tropicana    40   9.018695     0   3.87  0.232865  0.248935
# 1          2  tropicana    46   8.723231     0   3.87  0.232865  0.248935
# 2          2  tropicana    47   8.253228     0   3.87  0.232865  0.248935
# 3          2  tropicana    48   8.987197     0   3.87  0.232865  0.248935
# 4          2  tropicana    50   9.093357     0   3.87  0.232865  0.248935
# ...      ...        ...   ...        ...   ...    ...       ...       ...
# 28746    137  tropicana   156  11.313498     1   2.49  0.209602  0.528362
# 28747    137  tropicana   157  10.628133     0   2.66  0.209602  0.528362
# 28748    137  tropicana   158   9.936535     0   3.11  0.209602  0.528362
# 28749    137  tropicana   159  10.855917     1   2.79  0.209602  0.528362
# 28750    137  tropicana   160  10.236525     0   2.88  0.209602  0.528362
#
#         ethnic     income   hhlarge   workwom   hval150  sstrdist   sstrvol  \
# ...

# %%
for i in df['brand'].unique():
    print(f"{i} ",df.loc[df['brand']==i,'price'].mean())
# Out:
# tropicana  2.870493315369468
# minute.maid  2.2411617784226348
# dominicks  1.7358088921131722

# %%
df.groupby('brand')['price'].mean()
# Out:
# brand
# dominicks      1.735809
# minute.maid    2.241162
# tropicana      2.870493
# Name: price, dtype: float64

# %%
##Find the mean, sum, std of price for every brand

# %%
df.groupby('brand').agg(['mean','sum','std'])
# Out:
#                  store                          week                     \
#                   mean     sum       std        mean     sum        std
# brand
# dominicks    80.883511  780445  35.57774  100.459944  969338  34.693512
# minute.maid  80.883511  780445  35.57774  100.459944  969338  34.693512
# tropicana    80.883511  780445  35.57774  100.459944  969338  34.693512
#
#               logmove                              feat  ...  sstrdist  \
#                  mean           sum       std      mean  ...       std
# brand                                                    ...
# dominicks    9.174831  88527.943226  1.192937  0.257021  ...  3.472506
# minute.maid  9.217278  88937.517267  0.985287  0.288527  ...  3.472506
# tropicana    9.111483  87916.698522  0.847380  0.166235  ...  3.472506
#
#               sstrvol                           cpdist5                \
#                  mean           sum       std      mean           sum
# brand
# ...

# %%
##For every brand find the mean price and sum of income

# %%
df.groupby('brand').agg({'price':'mean','income':'sum'})
# Out:
#                 price         income
# brand
# dominicks    1.735809  102440.872522
# minute.maid  2.241162  102440.872522
# tropicana    2.870493  102440.872522

# %%
##Find the average income for each brand and at each store

# %%
df.groupby(['brand','store'])['income'].mean()
# Out:
# brand      store
# dominicks  2        10.553205
#            5        10.922371
#            8        10.597010
#            9        10.787152
#            12        9.996659
#                       ...
# tropicana  130       9.966650
#            131      10.793537
#            132      10.619154
#            134      10.722518
#            137      10.966490
# Name: income, Length: 249, dtype: float64

# %%
Find:
Mean and std deviation of the income
For income greater than or equal to 10.5, find the mean income
For each brand having price >=2.5 find the mean, median, sd of the log of income
Find the Cross tabulation of brands and feature advertisement
