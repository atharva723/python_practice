# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('./health_insurance_risk_dataset.csv')
df.head(3)
# Out:
#   policy_id  age  gender   bmi smoker region  annual_income occupation  \
# 0   P100000   59    Male  33.3     No   West        1080761   Salaried
# 1   P100001   49  Female  26.1    Yes   West         865752   Salaried
# 2   P100002   35    Male  20.9     No   East         787147   Salaried
#
#   marital_status  number_of_dependents  exercise_frequency chronic_disease  \
# 0         Single                     3                   4              No
# 1         Single                     4                   6             Yes
# 2         Single                     0                   6              No
#
#    past_claims_count  credit_score  policy_tenure_years  coverage_amount  \
# 0                  1           716                    2           400000
# 1                  2           522                   11           200000
# 2                  0           708                   10           500000
#
#    premium_amount  claim_occurred  claim_amount
# 0           28795               1        172010
# 1           37715               1         21049
# 2           25135               1        148269

# %% [markdown]
# # PART 1: EDA (Exploratory Data Analysis)

# %%
#missing values
#df.isnull().sum()
#df.describe()
df=df.iloc[:,1:]
df
# Out:
#       age  gender   bmi smoker region  annual_income     occupation  \
# 0      59    Male  33.3     No   West        1080761       Salaried
# 1      49  Female  26.1    Yes   West         865752       Salaried
# 2      35    Male  20.9     No   East         787147       Salaried
# 3      63  Female  27.5     No  North        1081382       Salaried
# 4      28    Male  26.5     No   East         955093       Salaried
# ...   ...     ...   ...    ...    ...            ...            ...
# 9995   53  Female  28.1     No   West         596573        Student
# 9996   21    Male  25.6     No   East         926145        Retired
# 9997   33    Male  24.5    Yes   West         720922  Self-Employed
# 9998   57    Male  30.2     No  North         868897  Self-Employed
# 9999   40    Male  29.5    Yes   East         707061       Salaried
#
#      marital_status  number_of_dependents  exercise_frequency chronic_disease  \
# 0            Single                     3                   4              No
# 1            Single                     4                   6             Yes
# 2            Single                     0                   6              No
# 3           Married                     2                   4              No
# 4            Single                     4                   6              No
# ...             ...                   ...                 ...             ...
# 9995        Married                     4                   4              No
# 9996         Single                     0                   1              No
# 9997         Single                     1                   3             Yes
# 9998        Married                     1                   0              No
# 9999         Single                     4                   1              No
#
#       past_claims_count  credit_score  policy_tenure_years  coverage_amount  \
# 0                     1           716                    2           400000
# 1                     2           522                   11           200000
# 2                     0           708                   10           500000
# 3                     2           756                    9           200000
# 4                     0           323                    6           400000
# ...                 ...           ...                  ...              ...
# 9995                  1           361                    2           500000
# 9996                  1           338                    6           300000
# 9997                  0           628                    5          1000000
# 9998                  0           456                   13           300000
# 9999                  3           720                    7          1000000
#
#       premium_amount  claim_occurred  claim_amount
# 0              28795               1        172010
# 1              37715               1         21049
# 2              25135               1        148269
# 3              22725               1         52861
# 4              21575               1        151403
# ...              ...             ...           ...
# 9995           29815               0             0
# 9996           17040               0             0
# 9997           58275               1        277761
# 9998           24930               1        103527
# 9999           52425               1        544732
#
# [10000 rows x 18 columns]

# %% [markdown]
# # outliers

# %%
# 2. Select the numerical column you want to check
# For this example, let's assume the column is named 'Price'
column_name = 'annual_income'

# 3. Create the visualization
plt.figure(figsize=(10, 6))
sns.boxplot(x=df[column_name])

# --- Understanding the Plot ---
# The 'Box': Represents the Interquartile Range (IQR), containing the middle 50% of the data.
# The 'Line' inside the box: This is the Median (the 50th percentile).
# The 'Whiskers': These extend to 1.5 times the IQR.
# The 'Dots/Diamonds': Any points beyond the whiskers are considered OUTLIERS.

plt.title(f'Box Plot of {column_name} to Identify Outliers')
plt.xlabel(column_name)
plt.show()

# %%
def find_all_outliers(data):
    outlier_dict = {}
    
    # Select only numerical columns (integers and floats)
    numeric_cols = data.select_dtypes(include=['number']).columns
    
    for col in numeric_cols:
        # Calculate Quatiles and IQR for the specific column
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        
        # Define the 'fences'
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        # Identify the outliers
        outliers = data[(data[col] < lower_bound) | (data[col] > upper_bound)][col]
        
        # Only add to dictionary if outliers actually exist
        if not outliers.empty:
            outlier_dict[col] = outliers.tolist()
            
    return outlier_dict

# Execute the function
all_outliers = find_all_outliers(df)

# Print the results
for column, values in all_outliers.items():
    print(f"Column '{column}' has {len(values)} ")
# Out:
# Column 'bmi' has 49
# Column 'annual_income' has 37
# Column 'past_claims_count' has 480
# Column 'premium_amount' has 24
# Column 'claim_amount' has 381
# Column 'claim_to_premium_ratio' has 110

# %%
# Quick way to see all boxplots at once
df.plot(kind='box', subplots=True, layout=(2, len(df.columns)//2 + 1), 
        figsize=(15, 10), sharex=False, sharey=False)
plt.tight_layout()
plt.show()

# %% [markdown]
#  # Distribution analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Load the insurance dataset
df = pd.read_csv('health_insurance_risk_dataset.csv')

# 2. Identify variable types for appropriate plotting
# Numerical: Continuous numbers | Categorical: Labels/Groups
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
cat_cols = df.select_dtypes(include=['object']).columns.tolist()

# Remove ID from visualization as it's just a unique string
if 'policy_id' in cat_cols: cat_cols.remove('policy_id')

# %%
# --- PLOTTING NUMERICAL DISTRIBUTIONS ---
# We use Histograms with a KDE (Kernel Density Estimate) line to see the shape
num_to_plot = [c for c in num_cols if c not in ['claim_occurred']] 
plt.figure(figsize=(20, 15))
for i, col in enumerate(num_to_plot):
    plt.subplot(4, 3, i + 1)
    sns.histplot(df[col], kde=True, color='teal')
    plt.title(f'Spread of {col}')
plt.tight_layout()
plt.show()

# %%
# --- PLOTTING CATEGORICAL FREQUENCIES ---
# We use CountPlots to see which groups are most frequent in the dataset
plt.figure(figsize=(20, 10))
for i, col in enumerate(cat_cols):
    plt.subplot(2, 3, i + 1)
    # Sort bars by frequency for better readability
    order = df[col].value_counts().index
    sns.countplot(data=df, x=col, order=order, palette='viridis')
    plt.title(f'Count by {col}')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# --- TARGET VARIABLE ANALYSIS ---
plt.figure(figsize=(12, 5))

# A. Binary Target: Are the classes balanced? (0 vs 1)
plt.subplot(1, 2, 1)
sns.countplot(x='claim_occurred', data=df, palette='Set2')
plt.title('Claim Occurred (Classification Target)')

# B. Regression Target: What is the range of claim payouts?
# Note: We filter for > 0 to see the actual distribution of paid claims
plt.subplot(1, 2, 2)
sns.histplot(df[df['claim_amount'] > 0]['claim_amount'], kde=True, color='orange')
plt.title('Claim Amount Distribution (Regression Target)')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Correlation Heatmap

# %%
 
# (Correlation requires numbers; categorical columns like 'smoker' must be encoded first)
df_numeric = df.select_dtypes(include=['int64', 'float64'])

# 3. Calculate the correlation matrix
corr_matrix = df_numeric.corr()

# 4. Plotting the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, 
            annot=True,       # Shows the correlation numbers in the boxes
            cmap='coolwarm',  # Color scale: Red (positive), Blue (negative)
            fmt='.2f',        # Rounds to 2 decimal places
            linewidths=0.5)

plt.title('Correlation Heatmap: Insurance Risk Features')
plt.show()

# %% [markdown]
# # Claim rate by: Age,Smoker,Chronic disease,Region.

# %% [raw]
# “For different groups of customers, what percentage of them filed a claim?”
#
# So we are not predicting yet.
# We are just doing EDA analysis to understand risk patterns.
#
# 🧠 What “Claim rate by X” means
#
# Claim rate = average of claim_occurred
#
# Because:
#
# claim_occurred = 1 → claim happened
#
# claim_occurred = 0 → no claim
#
# So the mean = percentage of people who claimed
#
# Example:
# If smoker group mean = 0.42
# → 42% smokers filed claims

# %% [markdown]
# ### Claim rate by Age

# %%
# We don’t group by exact age (too many values).
# We create age groups (bins).

# Create age bins
df['age_group'] = pd.cut(df['age'],
                         bins=[18, 30, 40, 50, 60, 80],
                         labels=['18-30','30-40','40-50','50-60','60+'])

# Claim rate by age group
age_claim = df.groupby('age_group')['claim_occurred'].mean()
print(age_claim)
# Out:
# age_group
# 18-30    0.592762
# 30-40    0.586040
# 40-50    0.585830
# 50-60    0.603626
# 60+      0.621518
# Name: claim_occurred, dtype: float64

# %%
age_claim.plot(kind='bar', title="Claim Rate by Age Group")
plt.ylabel("Claim Rate")
plt.show()

# %% [markdown]
# ### Claim rate by smoker

# %%
df.groupby('smoker')['claim_occurred'].mean()
# Out:
# smoker
# No     0.589021
# Yes    0.623361
# Name: claim_occurred, dtype: float64

# %%
sns.barplot(x='smoker', y='claim_occurred', data=df)
plt.title("Claim Rate by Smoker")
plt.show()

# %% [markdown]
# ### Claim rate by chronic disease

# %%
df.groupby('chronic_disease')['claim_occurred'].mean()
# Out:
# chronic_disease
# No     0.590903
# Yes    0.623797
# Name: claim_occurred, dtype: float64

# %%
sns.barplot(x='chronic_disease', y='claim_occurred', data=df)
plt.title("Claim Rate by Chronic Disease")
plt.show()

# %% [markdown]
# ### Claim rate by Regions

# %%
df.groupby('region')['claim_occurred'].mean()
# Out:
# region
# East     0.593611
# North    0.599272
# South    0.590347
# West     0.606203
# Name: claim_occurred, dtype: float64

# %%
sns.barplot(x='region', y='claim_occurred', data=df)
plt.title("Claim Rate by Region")
plt.show()

# %% [markdown]
# # Premium vs Claim Amount Analysis

# %% [raw]
# Are customers who pay higher premiums actually claiming more money?
# Is pricing aligned with risk?
# This is a regression relationship check between:
# ---premium_amount (what customer pays)
# ---claim_amount (what company pays out)

# %% [raw]
# What we check here:
# 1.Scatter relationship (visual trend)
# 2.Correlation value
# 3.Outliers
# 4.High premium but low claim?
# 5.Low premium but high claim? → dangerous customers

# %%
# Scatter plot to see relationship between premium and claim amount
plt.figure(figsize=(8,6))

# Each dot = one customer
sns.scatterplot(x='premium_amount', y='claim_amount', data=df)

# Title and labels
plt.title("Premium vs Claim Amount")
plt.xlabel("Premium Paid (₹)")
plt.ylabel("Claim Amount (₹)")
plt.show()
# Upward trend → good pricing
# Random scatter → weak relationship
# High claim with low premium → risky customers
# High premium but no claim → profitable customers

# %%
plt.figure(figsize=(8,6))

# regplot adds regression line
sns.regplot(x='premium_amount', y='claim_amount', data=df, scatter_kws={'alpha':0.5})

plt.title("Premium vs Claim Amount (with trend line)")
plt.show()

# %%
# Correlation tells strength of linear relationship
corr = df['premium_amount'].corr(df['claim_amount'])

print("Correlation between Premium and Claim:", corr)
# Interpretation
# Correlation	Meaning
# 0.0–0.2	Very weak
# 0.2–0.4	Moderate
# 0.4–0.6	Good
# 0.6+	Strong
# Out:
# Correlation between Premium and Claim: 0.33408185198236584

# %%
# Filter only customers who actually filed claims
claimed = df[df['claim_occurred'] == 1]

plt.figure(figsize=(8,6))
sns.scatterplot(x='premium_amount', y='claim_amount', data=claimed)
plt.title("Premium vs Claim Amount (Only Claimed Customers)")
plt.show()

# %%
# Claim to premium ratio
df['claim_to_premium_ratio'] = df['claim_amount'] / df['premium_amount']

# Replace inf values
df['claim_to_premium_ratio'] = df['claim_to_premium_ratio'].replace([float('inf')], 0)

df['claim_to_premium_ratio'].describe()

# If ratio > 1:
# 👉 Company is losing money on that customer
# Out:
# count    10000.000000
# mean         3.671689
# std          4.159272
# min          0.000000
# 25%          0.000000
# 50%          2.632509
# 75%          6.294634
# max         26.164312
# Name: claim_to_premium_ratio, dtype: float64

# %%
# Customers where claim > premium
loss_customers = df[df['claim_amount'] > df['premium_amount']]

print("Customers causing loss:", len(loss_customers))
# Out:
# Customers causing loss: 5682

# %% [markdown]
# # Class imbalance detection

# %% [raw]
# We check whether the target variable
# claim_occurred (0/1)
# has unequal distribution.
#
# Example:
# 90% → No claim
# 10% → Claim
# This = imbalanced dataset
#
# Why important?
# Imbalanced data can make models biased toward majority class.

# %%
# Count number of 0 and 1
df['claim_occurred'].value_counts()
# Out:
# claim_occurred
# 1    5974
# 0    4026
# Name: count, dtype: int64

# %%
# Percentage distribution
df['claim_occurred'].value_counts(normalize=True) * 100
# Out:
# claim_occurred
# 1    59.74
# 0    40.26
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='claim_occurred', data=df)
plt.title("Class Distribution: Claim Occurred")
plt.show()
# Distribution	Meaning
# 50–50	Balanced
# 70–30	Slight imbalance
# 80–20	Imbalanced
# 90–10	Highly imbalanced

# %%
ratio = df['claim_occurred'].value_counts(normalize=True)

print(ratio)

if ratio[1] < 0.3:
    print("⚠️ Dataset is imbalanced")
else:
    print("✅ Dataset is fairly balanced")
# Out:
# claim_occurred
# 1    0.5974
# 0    0.4026
# Name: proportion, dtype: float64
# ✅ Dataset is fairly balanced

# %% [markdown]
# # PART 2: Data Preprocessing

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns=['claim_occurred','claim_amount'])
y_class = df['claim_occurred']
y_reg = df['claim_amount']

X_train, X_test, y_train_class, y_test_class = train_test_split(
    X, y_class, test_size=0.2, random_state=42, stratify=y_class
)

# %%
X
# Out:
#       age  gender   bmi smoker region  annual_income     occupation  \
# 0      59    Male  33.3     No   West        1080761       Salaried
# 1      49  Female  26.1    Yes   West         865752       Salaried
# 2      35    Male  20.9     No   East         787147       Salaried
# 3      63  Female  27.5     No  North        1081382       Salaried
# 4      28    Male  26.5     No   East         955093       Salaried
# ...   ...     ...   ...    ...    ...            ...            ...
# 9995   53  Female  28.1     No   West         596573        Student
# 9996   21    Male  25.6     No   East         926145        Retired
# 9997   33    Male  24.5    Yes   West         720922  Self-Employed
# 9998   57    Male  30.2     No  North         868897  Self-Employed
# 9999   40    Male  29.5    Yes   East         707061       Salaried
#
#      marital_status  number_of_dependents  exercise_frequency chronic_disease  \
# 0            Single                     3                   4              No
# 1            Single                     4                   6             Yes
# 2            Single                     0                   6              No
# 3           Married                     2                   4              No
# 4            Single                     4                   6              No
# ...             ...                   ...                 ...             ...
# 9995        Married                     4                   4              No
# 9996         Single                     0                   1              No
# 9997         Single                     1                   3             Yes
# 9998        Married                     1                   0              No
# 9999         Single                     4                   1              No
#
#       past_claims_count  credit_score  policy_tenure_years  coverage_amount  \
# 0                     1           716                    2           400000
# 1                     2           522                   11           200000
# 2                     0           708                   10           500000
# 3                     2           756                    9           200000
# 4                     0           323                    6           400000
# ...                 ...           ...                  ...              ...
# 9995                  1           361                    2           500000
# 9996                  1           338                    6           300000
# 9997                  0           628                    5          1000000
# 9998                  0           456                   13           300000
# 9999                  3           720                    7          1000000
#
#       premium_amount
# 0              28795
# 1              37715
# 2              25135
# 3              22725
# 4              21575
# ...              ...
# 9995           29815
# 9996           17040
# 9997           58275
# 9998           24930
# 9999           52425
#
# [10000 rows x 16 columns]

# %% [markdown]
# ## Handling outliers

# %% [raw]
# If the outlier is...,Recommended Action
# A Measurement Error,Delete (Trimming) or Impute with Median.
# A Genuine Extreme Event,"Keep it, but use Robust Scaling or Capping."
# In a small dataset,Capping or Transformation (Don't delete!).
# In a huge dataset,Trimming is usually safe and fast.
#
#
# using IQR capping (Winsorization).

# %%
import numpy as np

num_cols = X_train.select_dtypes(include=['int64','float64']).columns

for col in num_cols:
    Q1 = X_train[col].quantile(0.25)
    Q3 = X_train[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    
    X_train[col] = np.clip(X_train[col], lower, upper)
    X_test[col] = np.clip(X_test[col], lower, upper)

# %% [markdown]
# ## Encoding

# %% [raw]
# Types of Encoding You’ll Use
#
# In this project mainly:
#
# 1️⃣ One-Hot Encoding
# Used when category has no order.
# Example:
# region = North, South, East, West
#
# We convert into new columns:
# region_North	region_South	region_East	region_West
# Each row gets 0 or 1.
#
# 2️⃣ Label Encoding (for binary)
# Use when column has only 2 values.
# Example:
# smoker → Yes/No
# chronic_disease → Yes/No
# gender → Male/Female
# Convert to:
# Yes=1
# No=0
#
# 3️⃣ Target Encoding (advanced)
# Used when:
# Too many categories
# Like occupation
# Many unique values
# Instead of creating 10 columns,
# we replace with average claim rate.
# Example:
# occupation	claim_occurred mean
# Doctor → 0.7
# Student → 0.2
# Then replace:
# Doctor → 0.7
# Student → 0.2

# %%
#one-hot encoding
X_train = pd.get_dummies(X_train, columns=['region','marital_status','occupation'], drop_first=True)
X_test = pd.get_dummies(X_test, columns=['region','marital_status','occupation'], drop_first=True)

# align columns
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

# %%
#label encoding
binary_cols = ['gender','smoker','chronic_disease']

for col in binary_cols:
    X_train[col] = X_train[col].map({'Yes':1,'No':0,'Male':1,'Female':0})
    X_test[col] = X_test[col].map({'Yes':1,'No':0,'Male':1,'Female':0})

# %% [markdown]
# ## Scaling

# %% [raw]
# The choice between Standardization (Standard Scaling) and Normalization (Min-Max Scaling) depends entirely on the shape of your data and the algorithm you plan to use.
#
# Min-Max Scaling (Normalization):
# This method "squashes" your data into a fixed range, usually 0 to 1.This is extremely sensitive to outliers.
#
# Standard Scaling (Standardization):
# This method centers the data around a mean of 0 with a standard deviation of 1.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

num_cols = X_train.select_dtypes(include=['int64','float64']).columns

X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_test[num_cols] = scaler.transform(X_test[num_cols])

# %% [markdown]
# ## Class Imbalance

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)

X_train, y_train_class = smote.fit_resample(X_train, y_train_class)
