# %% [markdown]
# # general usage
# Modules and packages
# data science = Numpy,Pandas , scipy, sklearn ,keras , pytorch
# iot = rasberry pie, ordinov,sockets
# testing= Junit

# %%
l=[1,1,3]
l1=l
print(l)
print(l1)
# Out:
# [1, 1, 3]
# [1, 1, 3]

# %%
## List comprehension

# %%
def args(**kwa):
    print(kwa)

# %%
args(a=1,b=2)
# Out:
# {'a': 1, 'b': 2}

# %%
## args kwargs

# %%
from functools import reduce

# %%
x= lambda x:len(x)**2 if len(x)%2==0 else len(x)

# %%
x([1,3,4])
# Out:
# 3

# %%
list(zip(range(6),"helloooo"))
# Out:
# [(0, 'h'), (1, 'e'), (2, 'l'), (3, 'l'), (4, 'o'), (5, 'o')]

# %%
from re import findall
print(findall(r'https?://', 'https://www.google.com'))
# Out:
# ['https://']
