# %% [markdown]
# # Data-types loops

# %% [markdown]
# ## string

# %%
v="hello hey damn"

# %%
v[::2]
# Out:
# 'hlohydm'

# %%
v[5]
# Out:
# ' '

# %%
for i,v in enumerate(v):
    print(i,v)
# Out:
# 0 h
# 1 e
# 2 l
# 3 l
# 4 o
# 5
# 6 h
# 7 e
# 8 y
# 9
# 10 d
# 11 a
# 12 m
# 13 n

# %%
d=enumerate(v)

# %%
for i in d:
    print(i)
# Out:
# (0, 'n')

# %%
s="hello"

# %%
s.capitalize()
# Out:
# 'Hello'

# %%
s.upper()
# Out:
# 'HELLO'

# %%
s='revive'

# %%
s.rsplit('v',1)
# Out:
# ['revi', 'e']

# %%
result='X'.join(s.rsplit('v',1))

# %%
result
# Out:
# 'reviXe'

# %% [markdown]
# ## Lists

# %%
l= [1,2,3,'helo','s',result]

# %%
l
# Out:
# [1, 2, 3, 'helo', 's', 'reviXe']

# %%
for i in dir(list):
    if i.startswith('__')==False:
         methods_lists.append(i)
print(methods_lists)
# Out:
# ['sort', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
methods_lists
# Out:
# ['sort',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
l=[]

# %%
l.append(["exit",'fail'])

# %% [markdown]
# ## DICTOINARY

# %%
d=dict()

# %%
d['Name']="Atharva"

# %%
d["age"]=23

# %%
d['sal']=2000

# %%
methods_dict=[]
for i in dir(dict):
    if i.startswith('__')==False:
         methods_dict.append(i)
print(methods_dict)
# Out:
# ['clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
d={'name':["Atharva","robert","david"],"sal":(2000,6000)}

# %%
d["name"].pop(d['name'].index('robert'))
# Out:
# 'robert'

# %%
d
# Out:
# {'name': ['Atharva', 'david'], 'sal': (2000, 6000)}

# %% [markdown]
# ## SET

# %%
s1=set()

# %%
type(s1)
# Out:
# set

# %%
s1={1,12323,2,2,42,43,42,42,42.1,42.0}

# %%
s1
# Out:
# {1, 2, 42, 42.1, 43, 12323}

# %%
s2={42,43,42.1,"hell"}

# %%
s1|s2
# Out:
# {1, 12323, 2, 42, 42.1, 43, 'hell'}

# %%
s1&s2
# Out:
# {42, 42.1, 43}

# %%
s2.issubset(s1)
# Out:
# False

# %%
s2.difference_update(s1)

# %%
s1
# Out:
# {1, 2, 42, 42.1, 43, 12323}

# %%
s2
# Out:
# {'hell'}

# %% [markdown]
# ## after break

# %%
bal = 29000
widthdraw=int(input("enter the amount to be withdraw: "))
print("the amount withdrawn is {} and the balance is {}".format(widthdraw,bal-widthdraw))
# Out:
# enter the amount to be withdraw:  1
# the amount withdrawn is 1 and the balance is 28999

# %% [markdown]
# ## conditions and iterations

# %%
sal= 10023

# %%
if sal>2000 and sal<40000:
    print("av")
else:
    print('chal')
# Out:
# av

# %%
if (sal>2000) and (sal<40000):
    print("av")
else:
    print('chal')
# Out:
# av

# %% [markdown]
# ## TASK

# %% [markdown]
# Ask user for input ,If the input is greater than zero. print positive
# also print whether it is multiples of 5,2
#     if not multiple of 5 or 2 ,print (neither divisible by 5 or 2 ) else negative

# %%
un=int(input("enter the no"))
if un>0 and  un%5==0 and un%2==0:
    print("positive and multiple of 5 and 2")
else:
    print('no ')
# Out:
# enter the no 10
# positive and multiple of 5 and 2

# %%
for i in range(10,21,2):
    print(i)
# Out:
# 10
# 12
# 14
# 16
# 18
# 20

# %%
for i in "hello":
    print(i,end="----")
# Out:
# h----e----l----l----o----

# %%
d
# Out:
# {'name': ['Atharva', 'david'], 'sal': (2000, 6000)}

# %%
for i in range(len(d['name'])):
    print("name is {} and is sal {}".format(d['name'][i],d['sal'][i]))
# Out:
# name is Atharva and is sal 2000
# name is david and is sal 6000

# %%
for i,j in d.items():
    print(i,":",j[1])
# Out:
# name : david
# sal : 6000

# %%
## Banana

# %%
s='Banana'
count=0
for i in range(len(s)):
    if s[i] in 'Aa':
        count+=1
        print(i,count)
# Out:
# 1 1
# 3 2
# 5 3

# %%
list(range(1,4))
# Out:
# [1, 2, 3]

# %%
#while

# %%
num=5
while num>0:
    if num==1:
        print('last')
    print(num)
    num-=1
# Out:
# 5
# 4
# 3
# 2
# last
# 1
